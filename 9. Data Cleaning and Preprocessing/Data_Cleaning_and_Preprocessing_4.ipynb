# %% [markdown]
# <a href="https://colab.research.google.com/github/anumit-web/ML-Analytics-Portfolio-2024/blob/main/9.%20Data%20Cleaning%20and%20Preprocessing/Data_Cleaning_and_Preprocessing_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Artificial Intelligence
# # Machine Learning
# # Portfolio Project
# # #9
# # Data Cleaning (v3)
# # Goal = Cleaning and preprocessing raw dataset. showcase of skills like data wrangling, feature engineering, data normalization
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# # Branding statement

# %%
# https://i.ibb.co/zZswY34/Pink-hands-network-2.png

# %%
from IPython.display import Image
Image('https://i.ibb.co/zZswY34/Pink-hands-network-2.png')

# %% [markdown]
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# # EDA, Exploratory Data Analysis

# %% [markdown]
# ## import libraries

# %%
print('Hello, Data Cleaning and Preprocessing')
# Out:
# Hello, Data Cleaning and Preprocessing

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# this library is used for one hot encoding
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Input data

# %%
# https://zenodo.org/records/13925131/files/netflix_titles.csv?download=1

input_data_df = pd.read_csv("https://zenodo.org/records/13925131/files/netflix_titles.csv"
                            , sep = ',')

# %%
number_of_rows = input_data_df.shape[0]
number_of_columns = input_data_df.shape[1]
print("Numner of rows = ", number_of_rows)
print("Number of columns = ", number_of_columns)
# Out:
# Numner of rows =  8807
# Number of columns =  12

# %%
input_data_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
input_data_df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# 8804   November 1, 2019          2009      R     88 min
# 8805   January 11, 2020          2006     PG     88 min
# 8806      March 2, 2019          2015  TV-14    111 min
#
#                                            listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
input_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
input_data_df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
#

# %%
# raise SystemExit("Stop right there!")

# %% [markdown]
# change index to date tyoe and date column

# %%
# input_data_df.index = input_data_df['Date']

# %%
input_data_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# do NOT drop date column because we need it for model training for linear and random forest algorithms

# %%
# input_data_df = input_data_df.drop('Date', axis=1)
# where 1 is the axis number (0 for rows and 1 for columns.)

# %%
input_data_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ## find list of all columns which have null values
#
# using SKIMPY

# %%
# Get the count of null values in each column
null_counts = input_data_df.isnull().sum()
print('Priniting count of null values = ')
print(null_counts)
# Out:
# Priniting count of null values =
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
try:
  import skimpy
except:
  # !pip install skimpy
  import skimpy

# %%
from skimpy import skim

# %%
skim(input_data_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 8807   │ │ string      │ 11    │                                                          │
# │ │ Number of columns │ 12     │ │ int64       │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name       ┃ NA   ┃ NA %   ┃ mean   ┃ sd      ┃ p0     ┃ p25    ┃ p50    ┃ p75    ┃ p100  ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━━━┩  │
# │ │ release_year      │    0 │      0 │   2014 │   8.819 │   1925 │   2013 │   2017 │   2019 │  2021 │     ▁▇  │  │
# │ └───────────────────┴──────┴────────┴────────┴─────────┴────────┴────────┴────────┴────────┴───────┴─────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name              ┃ NA         ┃ NA %         ┃ words per row              ┃ total words            ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ show_id                  │          0 │            0 │                          1 │                   8807 │  │
# │ │ type                     │          0 │            0 │                        1.3 │                  11483 │  │
# │ │ title                    │          0 │            0 │                        3.1 │                  27391 │  │
# │ │ director                 │       2634 │        29.91 │                        1.7 │                  14691 │  │
# │ │ cast                     │        825 │         9.37 │                         15 │                 132059 │  │
# │ │ country                  │        831 │         9.44 │                        1.7 │                  15066 │  │
# │ │ date_added               │         10 │         0.11 │                          3 │                  26479 │  │
# │ │ rating                   │          4 │         0.05 │                          1 │                   8806 │  │
# │ │ duration                 │          3 │         0.03 │                          2 │                  17608 │  │
# │ │ listed_in                │          0 │            0 │                        4.5 │                  39221 │  │
# │ │ description              │          0 │            0 │                         24 │                 210327 │  │
# │ └──────────────────────────┴────────────┴──────────────┴────────────────────────────┴────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ## find unique values by column names

# %%
# Find the number of unique values in both 'Name' and 'Age' columns
unique_values = input_data_df.nunique()
print(unique_values)
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
# ! pip install summarytools

try:
  import summarytools
except:
  # !pip install summarytools
  import summarytools

# %%
from summarytools import dfSummary

# %%
dfSummary(input_data_df)
# Out:
# <style type="text/css">
# #T_b2bec thead>tr>th {
#   text-align: left;
# }
# #T_b2bec_row0_col0, #T_b2bec_row1_col0, #T_b2bec_row2_col0, #T_b2bec_row3_col0, #T_b2bec_row4_col0, #T_b2bec_row5_col0, #T_b2bec_row6_col0, #T_b2bec_row7_col0, #T_b2bec_row8_col0, #T_b2bec_row9_col0, #T_b2bec_row10_col0, #T_b2bec_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_b2bec_row0_col1, #T_b2bec_row1_col1, #T_b2bec_row2_col1, #T_b2bec_row3_col1, #T_b2bec_row4_col1, #T_b2bec_row5_col1, #T_b2bec_row6_col1, #T_b2bec_row7_col1, #T_b2bec_row8_col1, #T_b2bec_row9_col1, #T_b2bec_row10_col1, #T_b2bec_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_b2bec_row0_col2, #T_b2bec_row1_col2, #T_b2bec_row2_col2, #T_b2bec_row3_col2, #T_b2bec_row4_col2, #T_b2bec_row5_col2, #T_b2bec_row6_col2, #T_b2bec_row7_col2, #T_b2bec_row8_col2, #T_b2bec_row9_col2, #T_b2bec_row10_col2, #T_b2bec_row11_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_b2bec_row0_col3, #T_b2bec_row1_col3, #T_b2bec_row2_col3, #T_b2bec_row3_col3, #T_b2bec_row4_col3, #T_b2bec_row5_col3, #T_b2bec_row6_col3, #T_b2bec_row7_col3, #T_b2bec_row8_col3, #T_b2bec_row9_col3, #T_b2bec_row10_col3, #T_b2bec_row11_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_b2bec_row0_col4, #T_b2bec_row1_col4, #T_b2bec_row2_col4, #T_b2bec_row3_col4, #T_b2bec_row4_col4, #T_b2bec_row5_col4, #T_b2bec_row6_col4, #T_b2bec_row7_col4, #T_b2bec_row8_col4, #T_b2bec_row9_col4, #T_b2bec_row10_col4, #T_b2bec_row11_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_b2bec_row0_col5, #T_b2bec_row1_col5, #T_b2bec_row2_col5, #T_b2bec_row3_col5, #T_b2bec_row4_col5, #T_b2bec_row5_col5, #T_b2bec_row6_col5, #T_b2bec_row7_col5, #T_b2bec_row8_col5, #T_b2bec_row9_col5, #T_b2bec_row10_col5, #T_b2bec_row11_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_b2bec" class="dataframe">
#   <caption><strong>Data Frame Summary</strong><br>input_data_df<br>Dimensions: 8,807 x 12<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_b2bec_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_b2bec_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_b2bec_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_b2bec_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_b2bec_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_b2bec_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b2bec_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b2bec_row0_col1" class="data row0 col1" ><strong>show_id</strong><br>[object]</td>
#       <td id="T_b2bec_row0_col2" class="data row0 col2" >1. s1<br>2. s5875<br>3. s5869<br>4. s5870<br>5. s5871<br>6. s5872<br>7. s5873<br>8. s5874<br>9. s5876<br>10. s5850<br>11. other</td>
#       <td id="T_b2bec_row0_col3" class="data row0 col3" >1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>8,797 (99.9%)</td>
#       <td id="T_b2bec_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_b2bec_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_b2bec_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_b2bec_row1_col1" class="data row1 col1" ><strong>type</strong><br>[object]</td>
#       <td id="T_b2bec_row1_col2" class="data row1 col2" >1. Movie<br>2. TV Show</td>
#       <td id="T_b2bec_row1_col3" class="data row1 col3" >6,131 (69.6%)<br>2,676 (30.4%)</td>
#       <td id="T_b2bec_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_b2bec_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_b2bec_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_b2bec_row2_col1" class="data row2 col1" ><strong>title</strong><br>[object]</td>
#       <td id="T_b2bec_row2_col2" class="data row2 col2" >1. Dick Johnson Is Dead<br>2. Ip Man 2<br>3. Hannibal Buress: Comedy Camisa<br>4. Turbo FAST<br>5. Masha's Tales<br>6. Chelsea Does<br>7. Ricardo O'Farrill Abrazo Genia<br>8. Ip Man<br>9. Tom Segura: Mostly Stories<br>10. Team Foxcatcher<br>11. other</td>
#       <td id="T_b2bec_row2_col3" class="data row2 col3" >1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>8,797 (99.9%)</td>
#       <td id="T_b2bec_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_b2bec_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_b2bec_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_b2bec_row3_col1" class="data row3 col1" ><strong>director</strong><br>[object]</td>
#       <td id="T_b2bec_row3_col2" class="data row3 col2" >1. nan<br>2. Rajiv Chilaka<br>3. Raúl Campos, Jan Suter<br>4. Suhas Kadav<br>5. Marcus Raboy<br>6. Jay Karas<br>7. Cathy Garcia-Molina<br>8. Jay Chapman<br>9. Youssef Chahine<br>10. Martin Scorsese<br>11. other</td>
#       <td id="T_b2bec_row3_col3" class="data row3 col3" >2,634 (29.9%)<br>19 (0.2%)<br>18 (0.2%)<br>16 (0.2%)<br>16 (0.2%)<br>14 (0.2%)<br>13 (0.1%)<br>12 (0.1%)<br>12 (0.1%)<br>12 (0.1%)<br>6,041 (68.6%)</td>
#       <td id="T_b2bec_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_b2bec_row3_col5" class="data row3 col5" >2,634<br>(29.9%)</td>
#     </tr>
#     <tr>
#       <td id="T_b2bec_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_b2bec_row4_col1" class="data row4 col1" ><strong>cast</strong><br>[object]</td>
#       <td id="T_b2bec_row4_col2" class="data row4 col2" >1. nan<br>2. David Attenborough<br>3. Vatsal Dubey, Julie Tejwani, R<br>4. Samuel West<br>5. Jeff Dunham<br>6. Craig Sechler<br>7. David Spade, London Hughes, Fo<br>8. Kevin Hart<br>9. Michela Luci, Jamie Watson, Er<br>10. Iliza Shlesinger<br>11. other</td>
#       <td id="T_b2bec_row4_col3" class="data row4 col3" >825 (9.4%)<br>19 (0.2%)<br>14 (0.2%)<br>10 (0.1%)<br>7 (0.1%)<br>6 (0.1%)<br>6 (0.1%)<br>6 (0.1%)<br>6 (0.1%)<br>5 (0.1%)<br>7,903 (89.7%)</td>
#       <td id="T_b2bec_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_b2bec_row4_col5" class="data row4 col5" >825<br>(9.4%)</td>
#     </tr>
#     <tr>
#       <td id="T_b2bec_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_b2bec_row5_col1" class="data row5 col1" ><strong>country</strong><br>[object]</td>
#       <td id="T_b2bec_row5_col2" class="data row5 col2" >1. United States<br>2. India<br>3. nan<br>4. United Kingdom<br>5. Japan<br>6. South Korea<br>7. Canada<br>8. Spain<br>9. France<br>10. Mexico<br>11. other</td>
#       <td id="T_b2bec_row5_col3" class="data row5 col3" >2,818 (32.0%)<br>972 (11.0%)<br>831 (9.4%)<br>419 (4.8%)<br>245 (2.8%)<br>199 (2.3%)<br>181 (2.1%)<br>145 (1.6%)<br>124 (1.4%)<br>110 (1.2%)<br>2,763 (31.4%)</td>
#       <td id="T_b2bec_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_b2bec_row5_col5" class="data row5 col5" >831<br>(9.4%)</td>
#     </tr>
#     <tr>
#       <td id="T_b2bec_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_b2bec_row6_col1" class="data row6 col1" ><strong>date_added</strong><br>[object]</td>
#       <td id="T_b2bec_row6_col2" class="data row6 col2" >1. January 1, 2020<br>2. November 1, 2019<br>3. March 1, 2018<br>4. December 31, 2019<br>5. October 1, 2018<br>6. November 1, 2018<br>7. July 1, 2021<br>8. October 1, 2019<br>9. September 1, 2021<br>10. January 1, 2018<br>11. other</td>
#       <td id="T_b2bec_row6_col3" class="data row6 col3" >10

# %% [markdown]
# # Data Cleanimg and Preprocessing 🧹🧼🧽

# %% [markdown]
# ## 101. Rename columns to better understand the data

# %%
input_data_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
input_data_df.columns = ['Show id', 'Media Type', 'Title',
                         'Director Name', 'Cast (Actors)', 'Country Name',
                         'Date Added', 'Release Year',
                         'Rating', 'Duration',
                         'Listed in Categories', 'Description']



input_data_df.head()
# Out:
#   Show id Media Type                  Title    Director Name  \
# 0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2    TV Show          Blood & Water              NaN
# 2      s3    TV Show              Ganglands  Julien Leclercq
# 3      s4    TV Show  Jailbirds New Orleans              NaN
# 4      s5    TV Show           Kota Factory              NaN
#
#                                        Cast (Actors)   Country Name  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            Date Added  Release Year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          Description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ## 101. Find duplicate rows

# %%
# Find duplicate rows
duplicate_rows = input_data_df[input_data_df.duplicated()]

# Print duplicate rows
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Show id, Media Type, Title, Director Name, Cast (Actors), Country Name, Date Added, Release Year, Rating, Duration, Listed in Categories, Description]
# Index: []

# %%
# Check if duplicates are found
if len(duplicate_rows) == 0:
    print("No duplicates found")
else:
    print("Duplicates found:")
# Out:
# No duplicates found

# %% [markdown]
# ## 101. Drop rows of data not needed
# 1. India and Paksitan
# 2. date added is null

# %%
# delete rows where A == 'foo'
# nput_data_df = input_data_df[input_data_df['A'] != 'foo']

# Delete rows using drop()
input_data_df = input_data_df.drop(input_data_df[input_data_df['Country Name'] == 'India'].index)

input_data_df = input_data_df.drop(input_data_df[input_data_df['Country Name'] == 'Pakistan'].index)


input_data_df.head()
# Out:
#   Show id Media Type                  Title    Director Name  \
# 0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2    TV Show          Blood & Water              NaN
# 2      s3    TV Show              Ganglands  Julien Leclercq
# 3      s4    TV Show  Jailbirds New Orleans              NaN
# 5      s6    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN
#
#            Date Added  Release Year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 5  The arrival of a charismatic young priest brin...

# %%
input_data_df.dropna(subset=['Date Added'], inplace=True)

input_data_df.head()
# Out:
#   Show id Media Type                  Title    Director Name  \
# 0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2    TV Show          Blood & Water              NaN
# 2      s3    TV Show              Ganglands  Julien Leclercq
# 3      s4    TV Show  Jailbirds New Orleans              NaN
# 5      s6    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN
#
#            Date Added  Release Year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 5  The arrival of a charismatic young priest brin...

# %% [markdown]
# ## 102. set value where null
# ## director name and other columns

# %%
# Set values where null
input_data_df.fillna('Not Given', inplace=True)

input_data_df.head()
# Out:
#   Show id Media Type                  Title    Director Name  \
# 0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2    TV Show          Blood & Water        Not Given
# 2      s3    TV Show              Ganglands  Julien Leclercq
# 3      s4    TV Show  Jailbirds New Orleans        Not Given
# 5      s6    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#            Date Added  Release Year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 5  The arrival of a charismatic young priest brin...

# %% [markdown]
# ## 103. Populate the country using the director column

# %%
# loc - rows and columns
director_and_country_names_df = input_data_df.loc[:, ['Director Name', 'Country Name']]

director_and_country_names_df.head()

#director_and_country_names_df.tail()
# Out:
#      Director Name   Country Name
# 0  Kirsten Johnson  United States
# 1        Not Given   South Africa
# 2  Julien Leclercq      Not Given
# 3        Not Given      Not Given
# 5    Mike Flanagan      Not Given

# %%
director_and_country_names_df = director_and_country_names_df.sort_values('Director Name')

director_and_country_names_df.head()
# Out:
#                        Director Name   Country Name
# 4049                 A.R. Murugadoss      Not Given
# 7374                     Aaron Burns          Chile
# 6434  Aaron Hancox, Michael McNamara         Canada
# 5892      Aaron Hann, Mario Miscione  United States
# 2778                    Aaron Lieber  United States

# %% [markdown]
# ## 104. Add a column

# %%
# add an integer column

input_data_df['Duration (in numbers)'] = 0

input_data_df.head()
# Out:
#   Show id Media Type                  Title    Director Name  \
# 0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2    TV Show          Blood & Water        Not Given
# 2      s3    TV Show              Ganglands  Julien Leclercq
# 3      s4    TV Show  Jailbirds New Orleans        Not Given
# 5      s6    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#            Date Added  Release Year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description  Duration (in numbers)
# 0  As her father nears the end of his life, filmm...                      0
# 1  After crossing paths at a party, a Cape Town t...                      0
# 2  To protect his family from a powerful drug lor...                      0
# 3  Feuds, flirtations and toilet talk go down amo...                      0
# 5  The arrival of a charismatic young priest brin...                      0

# %% [markdown]
# ## 105. Convert columns to integer or float values

# %%
# Split numbers from strings using str.replace()

input_data_df['Duration (in numbers)'] = input_data_df['Duration'].str.replace('[a-zA-Z]', '', regex=True)

input_data_df.head()
# Out:
#   Show id Media Type                  Title    Director Name  \
# 0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2    TV Show          Blood & Water        Not Given
# 2      s3    TV Show              Ganglands  Julien Leclercq
# 3      s4    TV Show  Jailbirds New Orleans        Not Given
# 5      s6    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#            Date Added  Release Year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description Duration (in numbers)
# 0  As her father nears the end of his life, filmm...                   90
# 1  After crossing paths at a party, a Cape Town t...                    2
# 2  To protect his family from a powerful drug lor...                    1
# 3  Feuds, flirtations and toilet talk go down amo...                    1
# 5  The arrival of a charismatic young priest brin...                    1

# %%
# Convert the 'ID' column to integer 64 type
# input_data_df['Duration (in numbers)'] = input_data_df['Duration (in numbers)'].astype('int64')

input_data_df["Duration (in numbers)"] = pd.to_numeric(input_data_df["Duration (in numbers)"], errors="coerce")



input_data_df.dtypes
# Out:
# Show id                   object
# Media Type                object
# Title                     object
# Director Name             object
# Cast (Actors)             object
# Country Name              object
# Date Added                object
# Release Year               int64
# Rating                    object
# Duration                  object
# Listed in Categories      object
# Description               object
# Duration (in numbers)    float64
# dtype: object

# %%
input_data_df.head()
# Out:
#   Show id Media Type                  Title    Director Name  \
# 0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2    TV Show          Blood & Water        Not Given
# 2      s3    TV Show              Ganglands  Julien Leclercq
# 3      s4    TV Show  Jailbirds New Orleans        Not Given
# 5      s6    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#            Date Added  Release Year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description  Duration (in numbers)
# 0  As her father nears the end of his life, filmm...                   90.0
# 1  After crossing paths at a party, a Cape Town t...                    2.0
# 2  To protect his family from a powerful drug lor...                    1.0
# 3  Feuds, flirtations and toilet talk go down amo...                    1.0
# 5  The arrival of a charismatic young priest brin...                    1.0

# %%
input_data_df['Duration (in numbers)'].isna().sum()
# Out:
# 3

# %%
# Fill missing values in the "Salary" column with the median salary
input_data_df['Duration (in numbers)'] = input_data_df['Duration (in numbers)'].fillna(0)

input_data_df.head()
# Out:
#   Show id Media Type                  Title    Director Name  \
# 0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2    TV Show          Blood & Water        Not Given
# 2      s3    TV Show              Ganglands  Julien Leclercq
# 3      s4    TV Show  Jailbirds New Orleans        Not Given
# 5      s6    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#            Date Added  Release Year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description  Duration (in numbers)
# 0  As her father nears the end of his life, filmm...                   90.0
# 1  After crossing paths at a party, a Cape Town t...                    2.0
# 2  To protect his family from a powerful drug lor...                    1.0
# 3  Feuds, flirtations and toilet talk go down amo...                    1.0
# 5  The arrival of a charismatic young priest brin...                    1.0

# %%
# Convert the 'ID' column to integer 64 type
input_data_df['Duration (in numbers)'] = input_data_df['Duration (in numbers)'].astype('int64')

input_data_df.head()
# Out:
#   Show id Media Type                  Title    Director Name  \
# 0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2    TV Show          Blood & Water        Not Given
# 2      s3    TV Show              Ganglands  Julien Leclercq
# 3      s4    TV Show  Jailbirds New Orleans        Not Given
# 5      s6    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#            Date Added  Release Year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description  Duration (in numbers)
# 0  As her father nears the end of his life, filmm...                     90
# 1  After crossing paths at a party, a Cape Town t...                      2
# 2  To protect his family from a powerful drug lor...                      1
# 3  Feuds, flirtations and toilet talk go down amo...                      1
# 5  The arrival of a charismatic young priest brin...                      1

# %% [markdown]
# ## 107. Remove leading/trailing whitespace (using lambda functions)

# %%
# Remove white space from only string columns

input_data_df= input_data_df.apply(lambda x: x.str.strip() if x.dtype == 'object' else x)

# print head and tail of dataframe
input_data_df
# Out:
#      Show id Media Type                  Title    Director Name  \
# 0         s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2    TV Show          Blood & Water        Not Given
# 2         s3    TV Show              Ganglands  Julien Leclercq
# 3         s4    TV Show  Jailbirds New Orleans        Not Given
# 5         s6    TV Show          Midnight Mass    Mike Flanagan
# ...      ...        ...                    ...              ...
# 8801   s8802      Movie                Zinzana  Majid Al Ansari
# 8802   s8803      Movie                 Zodiac    David Fincher
# 8803   s8804    TV Show            Zombie Dumb        Not Given
# 8804   s8805      Movie             Zombieland  Ruben Fleischer
# 8805   s8806      Movie                   Zoom     Peter Hewitt
#
#                                           Cast (Actors)  \
# 0                                             Not Given
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                             Not Given
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                          Not Given
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
#
#                       Country Name          Date Added  Release Year Rating  \
# 0                    United States  September 25, 2021          2020  PG-13
# 1                     South Africa  September 24, 2021          2021  TV-MA
# 2                        Not Given  September 24, 2021          2021  TV-MA
# 3                        Not Given  September 24, 2021          2021  TV-MA
# 5                        Not Given  September 24, 2021          2021  TV-MA
# ...                            ...                 ...           ...    ...
# 8801  United Arab Emirates, Jordan       March 9, 2016          2015  TV-MA
# 8802                 United States   November 20, 2019          2007      R
# 8803                     Not Given        July 1, 2019          2018  TV-Y7
# 8804                 United States    November 1, 2019          2009      R
# 8805                 United States    January 11, 2020          2006     PG
#
#        Duration                               Listed in Categories  \
# 0        90 min                                      Documentaries
# 1     2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2      1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3      1 Season                             Docuseries, Reality TV
# 5      1 Season                 TV Dramas, TV Horror, TV Mysteries
# ...         ...                                                ...
# 8801     96 min            Dramas, International Movies, Thrillers
# 8802    158 min                     Cult Movies, Dramas, Thrillers
# 8803  2 Seasons             Kids' TV, Korean TV Shows, TV Comedies
# 8804     88 min                            Comedies, Horror Movies
# 8805     88 min                 Children & Family Movies, Comedies
#
#                                             Description  Duration (in numbers)
# 0     As her father nears the end of his life, filmm...                     90
# 1     After crossing paths at a party, a Cape Town t...                      2
# 2     To protect his family from a powerful drug lor...                      1
# 3     Feuds, flirtations and toilet talk go down amo...                      1
# 5     The arrival of a charismatic young priest brin...                      1
# ...                                                 ...                    ...
# 8801  Recovering alcoholic Talal wakes up inside a s...                     96
# 8802  A political cartoonist, a crime reporter and a...                    158
# 8803  While living alone in a spooky town, a young g...                      2
# 8804  Looking to survive in a world taken over by zo...                     88
# 8805  Dragged from civilian life, a former superhero...                     88
#
# [7807 rows x 13 columns]

# %% [markdown]
# ## 107. Convert columns to date types

# %%
# Convert the 'Date' column to date type
input_data_df['Date Added'] = pd.to_datetime(input_data_df['Date Added'], format='%B %d, %Y')

input_data_df.dtypes
# Out:
# Show id                          object
# Media Type                       object
# Title                            object
# Director Name                    object
# Cast (Actors)                    object
# Country Name                     object
# Date Added               datetime64[ns]
# Release Year                      int64
# Rating                           object
# Duration                         object
# Listed in Categories             object
# Description                      object
# Duration (in numbers)             int64
# dtype: object

# %% [markdown]
# ## 115. Clone column

# %%
# Clone the 'Age' column to a new column 'Age_Clone' using the `copy()` function
input_data_df['Show id (new)'] = input_data_df['Show id'].copy()

input_data_df.head()
# Out:
#   Show id Media Type                  Title    Director Name  \
# 0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2    TV Show          Blood & Water        Not Given
# 2      s3    TV Show              Ganglands  Julien Leclercq
# 3      s4    TV Show  Jailbirds New Orleans        Not Given
# 5      s6    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#   Date Added  Release Year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 5 2021-09-24          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description  Duration (in numbers)  \
# 0  As her father nears the end of his life, filmm...                     90
# 1  After crossing paths at a party, a Cape Town t...                      2
# 2  To protect his family from a powerful drug lor...                      1
# 3  Feuds, flirtations and toilet talk go down amo...                      1
# 5  The arrival of a charismatic young priest brin...                      1
#
#   Show id (new)
# 0            s1
# 1            s2
# 2            s3
# 3            s4
# 5            s6

# %% [markdown]
# ## 120. Create new index using row identifier

# %%
# Set the 'Name' column as the index

input_data_df.set_index('Show id', inplace=True)

input_data_df.head()
# Out:
#         Media Type                  Title    Director Name  \
# Show id
# s1           Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2         TV Show          Blood & Water        Not Given
# s3         TV Show              Ganglands  Julien Leclercq
# s4         TV Show  Jailbirds New Orleans        Not Given
# s6         TV Show          Midnight Mass    Mike Flanagan
#
#                                              Cast (Actors)   Country Name  \
# Show id
# s1                                               Not Given  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# s4                                               Not Given      Not Given
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#         Date Added  Release Year Rating   Duration  \
# Show id
# s1      2021-09-25          2020  PG-13     90 min
# s2      2021-09-24          2021  TV-MA  2 Seasons
# s3      2021-09-24          2021  TV-MA   1 Season
# s4      2021-09-24          2021  TV-MA   1 Season
# s6      2021-09-24          2021  TV-MA   1 Season
#
#                                       Listed in Categories  \
# Show id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s6                      TV Dramas, TV Horror, TV Mysteries
#
#                                                Description  \
# Show id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s6       The arrival of a charismatic young priest brin...
#
#          Duration (in numbers) Show id (new)
# Show id
# s1                          90            s1
# s2                           2            s2
# s3                           1            s3
# s4                           1            s4
# s6                           1            s6

# %% [markdown]
# ## 125. Reset index if needed

# %%
# Do NOT move the index to a column
input_data_df.reset_index(drop=True, inplace=True)

input_data_df.head()
# Out:
#   Media Type                  Title    Director Name  \
# 0      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1    TV Show          Blood & Water        Not Given
# 2    TV Show              Ganglands  Julien Leclercq
# 3    TV Show  Jailbirds New Orleans        Not Given
# 4    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 4  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#   Date Added  Release Year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description  Duration (in numbers)  \
# 0  As her father nears the end of his life, filmm...                     90
# 1  After crossing paths at a party, a Cape Town t...                      2
# 2  To protect his family from a powerful drug lor...                      1
# 3  Feuds, flirtations and toilet talk go down amo...                      1
# 4  The arrival of a charismatic young priest brin...                      1
#
#   Show id (new)
# 0            s1
# 1            s2
# 2            s3
# 3            s4
# 4            s6

# %% [markdown]
# ## 130. Drop columns not needed

# %%
# Drop the 'Age' column
# axis 1 = column, 0 = rows
input_data_df = input_data_df.drop('Show id (new)', axis=1)

input_data_df.head()
# Out:
#   Media Type                  Title    Director Name  \
# 0      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1    TV Show          Blood & Water        Not Given
# 2    TV Show              Ganglands  Julien Leclercq
# 3    TV Show  Jailbirds New Orleans        Not Given
# 4    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 4  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#   Date Added  Release Year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description  Duration (in numbers)
# 0  As her father nears the end of his life, filmm...                     90
# 1  After crossing paths at a party, a Cape Town t...                      2
# 2  To protect his family from a powerful drug lor...                      1
# 3  Feuds, flirtations and toilet talk go down amo...                      1
# 4  The arrival of a charismatic young priest brin...                      1

# %% [markdown]
# ## 135. Convert minutes to hours and minutes

# %%
# create new column to store time values

input_data_df['Time'] = ''

input_data_df.head()
# Out:
#   Media Type                  Title    Director Name  \
# 0      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1    TV Show          Blood & Water        Not Given
# 2    TV Show              Ganglands  Julien Leclercq
# 3    TV Show  Jailbirds New Orleans        Not Given
# 4    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 4  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#   Date Added  Release Year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description  Duration (in numbers)  \
# 0  As her father nears the end of his life, filmm...                     90
# 1  After crossing paths at a party, a Cape Town t...                      2
# 2  To protect his family from a powerful drug lor...                      1
# 3  Feuds, flirtations and toilet talk go down amo...                      1
# 4  The arrival of a charismatic young priest brin...                      1
#
#   Time
# 0
# 1
# 2
# 3
# 4

# %%
# Print unique values of the 'Name' column
print(input_data_df['Media Type'].unique())
# Out:
# ['Movie' 'TV Show']

# %%
# Convert the Age column to string
input_data_df['Media Type'] = input_data_df['Media Type'].astype(str)

# Define a simple function to convert age to string
def minutes_to_hours_and_minutes_2(row_input):
    return_value = ''
    if(row_input['Media Type'] == 'Movie'):
        hours_output = int(row_input['Duration (in numbers)']) // 60
        minutes_output = int(row_input['Duration (in numbers)']) % 60
        return_value = '' + str(hours_output) + ' hours ' + str(minutes_output) + ' minutes'
    return str(return_value)


input_data_df['Time'] = input_data_df.apply(minutes_to_hours_and_minutes_2, axis=1)

input_data_df.head()
# Out:
#   Media Type                  Title    Director Name  \
# 0      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1    TV Show          Blood & Water        Not Given
# 2    TV Show              Ganglands  Julien Leclercq
# 3    TV Show  Jailbirds New Orleans        Not Given
# 4    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 4  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#   Date Added  Release Year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description  Duration (in numbers)  \
# 0  As her father nears the end of his life, filmm...                     90
# 1  After crossing paths at a party, a Cape Town t...                      2
# 2  To protect his family from a powerful drug lor...                      1
# 3  Feuds, flirtations and toilet talk go down amo...                      1
# 4  The arrival of a charismatic young priest brin...                      1
#
#                  Time
# 0  1 hours 30 minutes
# 1
# 2
# 3
# 4

# %% [markdown]
# ## 140. One hot encoding

# %% [markdown]
# ## Use label encoder instead of one hot encoder or ordinal encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
input_data_df['Media Type Encoded'] = label_encoder.fit_transform(input_data_df['Media Type'])

input_data_df.head()
# Out:
#   Media Type                  Title    Director Name  \
# 0      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1    TV Show          Blood & Water        Not Given
# 2    TV Show              Ganglands  Julien Leclercq
# 3    TV Show  Jailbirds New Orleans        Not Given
# 4    TV Show          Midnight Mass    Mike Flanagan
#
#                                        Cast (Actors)   Country Name  \
# 0                                          Not Given  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...      Not Given
# 3                                          Not Given      Not Given
# 4  Kate Siegel, Zach Gilford, Hamish Linklater, H...      Not Given
#
#   Date Added  Release Year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA   1 Season
#
#                                 Listed in Categories  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4                 TV Dramas, TV Horror, TV Mysteries
#
#                                          Description  Duration (in numbers)  \
# 0  As her father nears the end of his life, filmm...                     90
# 1  After crossing paths at a party, a Cape Town t...                      2
# 2  To protect his family from a powerful drug lor...                      1
# 3  Feuds, flirtations and toilet talk go down amo...                      1
# 4  The arrival of a charismatic young priest brin...                      1
#
#                  Time  Media Type Encoded
# 0  1 hours 30 minutes                   0
# 1                                       1
# 2                                       1
# 3                                       1
# 4                                       1

# %% [markdown]
# ## 999. Stop execution

# %%
# raise SystemExit("Stop right there!")

# %%
# raise SystemExit("Stop right there!")

# %% [markdown]
# # Data Visualization 📊📈📉

# %% [markdown]
# ## Sheet 1. Content type in percentage

# %%
pie_df    = input_data_df[['Media Type']]

pie_df.head()
# Out:
#   Media Type
# 0      Movie
# 1    TV Show
# 2    TV Show
# 3    TV Show
# 4    TV Show

# %%
# pie_df    = input_data_df[['Media Type']]

# Count the number of occurrences of each category
counts = pie_df['Media Type'].value_counts()

# Create a pie chart
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7b28c3434820>,
#   <matplotlib.patches.Wedge at 0x7b28c3434a00>],
#  [Text(-0.5573946155687564, 0.948320221515369, 'Movie'),
#   Text(0.5573946155687562, -0.9483202215153691, 'TV Show')],
#  [Text(-0.30403342667386707, 0.5172655753720193, '66.9%'),
#   Text(0.304033426673867, -0.5172655753720194, '33.1%')])

# %% [markdown]
# ## Sheet 2. Movie & TV Show by Country

# %%
# Create a new DataFrame with two columns from the existing DataFrame
stacked_bar_df = input_data_df[['Media Type', 'Country Name']]

# Print the new DataFrame
stacked_bar_df.head()
# Out:
#   Media Type   Country Name
# 0      Movie  United States
# 1    TV Show   South Africa
# 2    TV Show      Not Given
# 3    TV Show      Not Given
# 4    TV Show      Not Given

# %%
# Filter out rows where the 'Category' column is 'B'
stacked_bar_df = stacked_bar_df[stacked_bar_df['Country Name'] != 'Not Given']

stacked_bar_df.head()
# Out:
#   Media Type                                       Country Name
# 0      Movie                                      United States
# 1    TV Show                                       South Africa
# 6      Movie  United States, Ghana, Burkina Faso, United Kin...
# 7    TV Show                                     United Kingdom
# 8      Movie                                      United States

# %%
# Count the number of rows in each category in the 'Category' column
counts_df = stacked_bar_df['Country Name'].value_counts()

# Select the top 10 categories by count of rows
top_10_categories_df = counts_df.head(10)

# Print the top 10 categories by count of rows
print(top_10_categories_df)
# Out:
# Country Name
# United States     2812
# United Kingdom     418
# Japan              244
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Turkey             105
# Name: count, dtype: int64

# %%
# Convert the index to a column
top_10_categories_df = top_10_categories_df.reset_index()

# Convert the 'Category' column to a list of values
category_list = top_10_categories_df['Country Name'].tolist()

# Print the list of values
print(category_list)
# Out:
# ['United States', 'United Kingdom', 'Japan', 'South Korea', 'Canada', 'Spain', 'France', 'Mexico', 'Egypt', 'Turkey']

# %%
# Filter rows in the 'Category' column only if the value is present in the list
stacked_bar_df = stacked_bar_df[stacked_bar_df['Country Name'].isin(category_list)]

# Print the filtered DataFrame
print(stacked_bar_df)
# Out:
#      Media Type    Country Name
# 0         Movie   United States
# 7       TV Show  United Kingdom
# 8         Movie   United States
# 14      TV Show   United States
# 16      TV Show          Mexico
# ...         ...             ...
# 7797      Movie   United States
# 7800    TV Show          Turkey
# 7803      Movie   United States
# 7805      Movie   United States
# 7806      Movie   United States
#
# [4444 rows x 2 columns]

# %%
# default order of printing bars is alpahbetical order

stacked_bar_df.groupby(['Country Name', 'Media Type']).size().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Country Name'>

# %%
# default order of printing bars is alpahbetical order

stacked_bar_df.groupby(['Country Name', 'Media Type']).size().unstack().plot(kind='barh', stacked=True)
# Out:
# <Axes: ylabel='Country Name'>

# %% [markdown]
# ## Sheet 3. Number of Contents Added through the Years

# %%
#
content_added_in_years_df = input_data_df['Release Year']

# convert series to frame
content_added_in_years_df = content_added_in_years_df.to_frame()

content_added_in_years_df.head()
# Out:
#    Release Year
# 0          2020
# 1          2021
# 2          2021
# 3          2021
# 4          2021

# %%
content_added_in_years_df.columns
# Out:
# Index(['Release Year'], dtype='object')

# %%
# Count the number of occurrences of each category in the 'Category' column
category_counts = content_added_in_years_df['Release Year'].value_counts().sort_values(ascending=False)

# Print the category counts
print(category_counts)
# Out:
# Release Year
# 2018    1049
# 2019     943
# 2017     926
# 2020     878
# 2016     824
#         ...
# 1925       1
# 1964       1
# 1961       1
# 1947       1
# 1969       1
# Name: count, Length: 72, dtype: int64

# %%
# Create a figure with a specified size
plt.figure(figsize=(20, 6))

# Create a line chart
category_counts.plot(kind='line')

# Add a title and labels for the axes
plt.title('Number of Contents Added through the Years')
plt.xlabel('Year')
plt.ylabel('Number of Moive and TV Show titles released that year')

# Display the chart
plt.show()

# %%
category_counts_df = category_counts.to_frame()

category_counts_df = category_counts_df.reset_index()

category_counts_df.head()

#
# sns.lineplot(x='Release Year', y='Euro rate', data=category_counts)
# Out:
#    Release Year  count
# 0          2018   1049
# 1          2019    943
# 2          2017    926
# 3          2020    878
# 4          2016    824

# %%
fig = plt.subplots(figsize=(15,7))
ax = sns.lineplot(data=category_counts_df, x="Release Year", y="count", marker = "o", markers=True, markevery=5).set(title='Number of Contents Added through the Years',
                                                                       xlabel='Year', ylabel='Numbers added')


# Add y-values at every marker

# Display the plot
plt.show()

# %% [markdown]
# ## Sheet 4. Top Directors

# %% [markdown]
# ## Sheet 5. Top Genres

# %% [markdown]
# ## Sheet 8. Content Types over the Years

# %%
content_types_over_the_years_df = input_data_df[['Media Type', 'Release Year', 'Date Added']].copy()

content_types_over_the_years_df['Date Added Year Only'] = content_types_over_the_years_df['Date Added'].dt.year


content_types_over_the_years_df.head()
# Out:
#   Media Type  Release Year Date Added  Date Added Year Only
# 0      Movie          2020 2021-09-25                  2021
# 1    TV Show          2021 2021-09-24                  2021
# 2    TV Show          2021 2021-09-24                  2021
# 3    TV Show          2021 2021-09-24                  2021
# 4    TV Show          2021 2021-09-24                  2021

# %%
# Count the number of occurrences of each category in the 'Category' column
category_counts = content_types_over_the_years_df.value_counts(
                    subset=['Date Added Year Only', 'Media Type'])

# print
print(category_counts)
# Out:
# Date Added Year Only  Media Type
# 2019                  Movie         1232
# 2020                  Movie         1112
# 2018                  Movie          916
# 2021                  Movie          913
# 2017                  Movie          707
# 2020                  TV Show        578
# 2019                  TV Show        575
# 2021                  TV Show        490
# 2018                  TV Show        395
# 2017                  TV Show        335
# 2016                  Movie          243
#                       TV Show        173
# 2015                  Movie           56
#                       TV Show         26
# 2014                  Movie           19
# 2011                  Movie           13
# 2013                  Movie            6
# 2014                  TV Show          5
# 2013                  TV Show          5
# 2012                  Movie            3
# 2009                  Movie            2
# 2008                  TV Show          1
# 2010                  Movie            1
# 2008                  Movie            1
# Name: count, dtype: int64

# %%
# Create a new column that contains the value counts of 'Column1' for each unique value of 'Column2'
content_types_over_the_years_df['Count'] = content_types_over_the_years_df['Date Added Year Only'].map(content_types_over_the_years_df.groupby('Media Type')['Date Added Year Only'].value_counts())

content_types_over_the_years_df.head()
# Out:
#   Media Type  Release Year Date Added  Date Added Year Only  Count
# 0      Movie          2020 2021-09-25                  2021    NaN
# 1    TV Show          2021 2021-09-24                  2021    NaN
# 2    TV Show          2021 2021-09-24                  2021    NaN
# 3    TV Show          2021 2021-09-24                  2021    NaN
# 4    TV Show          2021 2021-09-24                  2021    NaN

# %%
# category

category_counts_df = category_counts.to_frame()

category_counts_df = category_counts_df.reset_index()

# print
category_counts_df
# Out:
#     Date Added Year Only Media Type  count
# 0                   2019      Movie   1232
# 1                   2020      Movie   1112
# 2                   2018      Movie    916
# 3                   2021      Movie    913
# 4                   2017      Movie    707
# 5                   2020    TV Show    578
# 6                   2019    TV Show    575
# 7                   2021    TV Show    490
# 8                   2018    TV Show    395
# 9                   2017    TV Show    335
# 10                  2016      Movie    243
# 11                  2016    TV Show    173
# 12                  2015      Movie     56
# 13                  2015    TV Show     26
# 14                  2014      Movie     19
# 15                  2011      Movie     13
# 16                  2013      Movie      6
# 17                  2014    TV Show      5
# 18                  2013    TV Show      5
# 19                  2012      Movie      3
# 20                  2009      Movie      2
# 21                  2008    TV Show      1
# 22                  2010      Movie      1
# 23                  2008      Movie      1

# %%
# category_counts_df  = category_counts_df.set_index('Date Added Year Only')

category_counts_df.head()
# Out:
#    Date Added Year Only Media Type  count
# 0                  2019      Movie   1232
# 1                  2020      Movie   1112
# 2                  2018      Movie    916
# 3                  2021      Movie    913
# 4                  2017      Movie    707

# %%
# df.pivot_table(index=['Country_1'], columns='Var_name', values='Year',aggfunc='first')

# df.pivot_table(index=['Media Type'], columns='Var_name', values='Year',aggfunc='first')


category_counts_movies_df = category_counts_df.loc[category_counts_df['Media Type'] == 'Movie']

category_counts_movies_df.head()
# Out:
#    Date Added Year Only Media Type  count
# 0                  2019      Movie   1232
# 1                  2020      Movie   1112
# 2                  2018      Movie    916
# 3                  2021      Movie    913
# 4                  2017      Movie    707

# %%
#

category_counts_tv_show_df = category_counts_df.loc[category_counts_df['Media Type'] == 'TV Show']

category_counts_tv_show_df.head()
# Out:
#    Date Added Year Only Media Type  count
# 5                  2020    TV Show    578
# 6                  2019    TV Show    575
# 7                  2021    TV Show    490
# 8                  2018    TV Show    395
# 9                  2017    TV Show    335

# %%
sns.set_style("dark")
sns.lineplot(x='Date Added Year Only', y='count', data=category_counts_movies_df)
sns.lineplot(x='Date Added Year Only', y='count', data=category_counts_tv_show_df)

#ax.legend()

plt.title("Content Types added over the Years")
plt.show()

# %%
raise SystemExit("Stop right there!")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stop right there!
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # The End 🛑
